# %% [markdown]
# <a href="https://colab.research.google.com/github/mithil1523/covid19-data-analysis/blob/main/Covid19_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Welcome to Covid19 Data Analysis Notebook**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# Task 2
# Task 2.1: importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
corona_dataset_csv = pd.read_csv('covid19_Confirmed_dataset.csv')
corona_dataset_csv.head(10)
#We will notice data is from 22 January 2020 to 30 April 2020
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
corona_dataset_csv.shape    #Tuple with 266 rows and 104 columns
# Out:
# (266, 104)

# %%
columns = corona_dataset_csv.columns
columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '4/21/20', '4/22/20', '4/23/20', '4/24/20', '4/25/20', '4/26/20',
#        '4/27/20', '4/28/20', '4/29/20', '4/30/20'],
#       dtype='object', length=104)

# %% [markdown]
# Task 2.2: Delete the useless columns

# %%
#Latitude and Longitude are not important features for us here
corona_dataset_csv.drop(["Lat",
                        "Long"],
                        axis=1,
                        #default value, annotation axis=0 which is equal to rows
                        inplace = True   #will change the corona dataset too
                        )

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# Task 2.3: Aggregating the rows by the country

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head()
#After aggregation, the index of the df is the column at which we aggregated
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan                 0        0        0        0        0        0
# Albania                     0        0        0        0        0        0
# Algeria                     0        0        0        0        0        0
# Andorra                     0        0        0        0        0        0
# Angola                      0        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...     1092     1176
# Albania               0        0        0        0  ...      609      634
# Algeria               0        0        0        0  ...     2811     2910
# Andorra               0        0        0        0  ...      717      723
# ...

# %%
corona_dataset_aggregated.shape
#we have 187 countries, 100 dates
# Out:
# (187, 101)

# %% [markdown]
# Task 2.4: Visualizing data related to a country for example China
# visualization always helps for better understanding of our data.

# %%
corona_dataset_aggregated.loc["China"]
#will return pandas series
# Out:
# Province/State    AnhuiBeijingChongqingFujianGansuGuangdongGuang...
# 1/22/20                                                         548
# 1/23/20                                                         643
# 1/24/20                                                         920
# 1/25/20                                                        1406
#                                         ...
# 4/26/20                                                       83912
# 4/27/20                                                       83918
# 4/28/20                                                       83940
# 4/29/20                                                       83944
# 4/30/20                                                       83956
# Name: China, Length: 101, dtype: object

# %% [markdown]
# Task3: Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
corona_dataset_aggregated.loc['China'] = pd.to_numeric(corona_dataset_aggregated.loc['China'], errors='coerce')
corona_dataset_aggregated.loc['China'].plot()
# Out:
# <Axes: >

# %%
corona_dataset_aggregated.loc['Egypt'].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['Spain'].plot()
plt.legend()

# %%
#Spread of the virus in China for the first 3 dates only
corona_dataset_aggregated.loc['China'][:3].plot()
# Out:
# <Axes: >

# %% [markdown]
# task 3.1: caculating the first derivative of the curve

# %%
corona_dataset_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %% [markdown]
# task 3.2: find maxmimum infection rate for China

# %%
corona_dataset_aggregated.loc["China"].diff().max()
#In only 24 hrs, the difference was 15136
# Out:
# 15136

# %%
corona_dataset_aggregated.loc["Italy"].diff().max()
#In only 24 hrs, the difference was 6557
# Out:
# 6557

# %%
corona_dataset_aggregated.loc["Spain"].diff().max()
#In only 24 hrs, the difference was 9630
# Out:
# 9630

# %% [markdown]
# Task 3.3: find maximum infection rate for all of the countries.

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for c in countries :
    # Convert the data to numeric before calculating the diff
    try:
        max_infection_rates.append(pd.to_numeric(corona_dataset_aggregated.loc[c]).diff().max())
    except (TypeError, ValueError):
        # Handle cases where conversion to numeric fails (e.g., non-numeric columns)
        print(f"Skipping country {c} due to non-numeric data.")
        max_infection_rates.append(np.nan) # or any other suitable value
max_infection_rates
# Out:
# Skipping country Australia due to non-numeric data.
# Skipping country Canada due to non-numeric data.
# Skipping country Denmark due to non-numeric data.
# Skipping country France due to non-numeric data.
# Skipping country Netherlands due to non-numeric data.
# Skipping country United Kingdom due to non-numeric data.
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  nan,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  nan,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  nan,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  nan,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
# ...

# %%
corona_dataset_aggregated["max_infection_rates"] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan                 0        0        0        0        0        0
# Albania                     0        0        0        0        0        0
# Algeria                     0        0        0        0        0        0
# Andorra                     0        0        0        0        0        0
# Angola                      0        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/22/20  4/23/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...     1176     1279
# Albania               0        0        0        0  ...      634      663
# Algeria               0        0        0        0  ...     2910     3007
# Andorra               0        0        0        0  ...      723      723
# ...

# %% [markdown]
# Task 3.4: create a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rates"])

# %%
corona_data.head()
# Out:
#                 max_infection_rates
# Country/Region
# Afghanistan                   232.0
# Albania                        34.0
# Algeria                       199.0
# Andorra                        43.0
# Angola                          5.0

# %% [markdown]
# Task4:
# -Importing the WorldHappinessReport.csv dataset
# -selecting needed columns for our analysis
# join the datasets
# -calculate the correlations as the result of our analysis
# Task 4.1 : importing the dataset

# %%
happiness_report_csv = pd.read_csv("worldwide_happiness_report.csv")

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# Task 4.2 let's drop the useless columns

# %%
useless_cols = ["Overall rank", "Score", "Generosity", "Perceptions of corruption"]

# %%
happiness_report_csv.drop(useless_cols, axis=1, inplace=True)
happiness_report_csv.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# Task 4.3 : changing indices of the dataframe

# %%
happiness_report_csv.set_index("Country or region", inplace=True)

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# Task 4.4 : now lets join two dataset we have prepared

# %%
corona_data.head()
# Out:
#                 max_infection_rates
# Country/Region
# Afghanistan                   232.0
# Albania                        34.0
# Algeria                       199.0
# Andorra                        43.0
# Angola                          5.0

# %%
corona_data.shape    #Tuple with 187 countries
# Out:
# (187, 1)

# %% [markdown]
# wolrd happiness report Dataset :

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happiness_report_csv.shape    #156 countries, less than corona data
# Out:
# (156, 4)

# %%
#Inner join
data = corona_data.join(happiness_report_csv,
                how = "inner"    #method/type of join
                )
data.head()
# Out:
#              max_infection_rates  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# Task 4.5: correlation matrix

# %%
data.corr()
# Out:
#                               max_infection_rates  GDP per capita  \
# max_infection_rates                      1.000000        0.245583
# GDP per capita                           0.245583        1.000000
# Social support                           0.175685        0.759468
# Healthy life expectancy                  0.277029        0.863062
# Freedom to make life choices             0.074337        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rates                 0.175685                 0.277029
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rates                               0.074337
# ...

# %% [markdown]
# **Task 5: Visualization of the results**
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
data.head()
# Out:
#              max_infection_rates  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# Task 5.1: Plotting GDP vs maximum Infection rate

# %%
x = data["GDP per capita"]
y = data["max_infection_rates"]
sns.scatterplot(x=x, y=y) # Changed this line to use named arguments

#We can see the values need different scaling
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infection_rates'>

# %%
#Will apply log scaling to y
x = data["GDP per capita"]
y = data["max_infection_rates"]
# sns.scatterplot(x,np.log(y))  # Incorrect: Passing x and y as positional arguments
sns.scatterplot(x='GDP per capita', y='max_infection_rates', data=data) # Correct: Using named arguments with 'data'
plt.yscale('log') # Apply log scaling to the y-axis

#Now we can see +ve correlation

# %%
#RegPlot
# x = data["GDP per capita"]  # No need to redefine x and y here
# y = data["max_infection_rates"]

# sns.regplot(x,np.log(y))  # Incorrect: Passing x and y as positional arguments

# Instead, use keyword arguments and 'data':
sns.regplot(x='GDP per capita', y='max_infection_rates', data=data)
plt.yscale('log')  # Apply log scaling to the y-axis

#Line fitted, +ve slope seen

# %% [markdown]
# Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x = data["Social support"]
y = data["max_infection_rates"]

# Instead of: sns.scatterplot(x, np.log(y))
# Use named arguments with 'data' or 'x' and 'y' explicitly:
sns.scatterplot(x=x, y=np.log(y))  # Option 1: Using x and y directly
# OR
sns.scatterplot(x='Social support', y='max_infection_rates', data=data)  # Option 2: Using data and column names
plt.yscale('log') #This will make the scatterplot more interpretable

# %%
x = data["Social support"]
y = data["max_infection_rates"]

# Instead of: sns.regplot(x, np.log(y))
# Use named arguments with 'x' and 'y':
sns.regplot(x=x, y=np.log(y))
#OR
#sns.regplot(x='Social support', y='max_infection_rates', data=data) # Option 2: Using data and column
# Out:
# <Axes: xlabel='Social support', ylabel='max_infection_rates'>

# %% [markdown]
# Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data["Healthy life expectancy"]
y = data["max_infection_rates"]

# Instead of: sns.scatterplot(x, np.log(y))
# Use named arguments with 'x' and 'y':
sns.scatterplot(x=x, y=np.log(y))
# OR
# Use the 'data' argument and specify column names:
# sns.scatterplot(x='Healthy life expectancy', y='max_infection_rates', data=data)
# plt.yscale('log') #This will make the scatterplot more interpretable
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_infection_rates'>

# %%
x = data["Healthy life expectancy"]
y = data["max_infection_rates"]

# Instead of: sns.regplot(x, np.log(y))
# Use named arguments with 'x' and 'y':
sns.regplot(x=x, y=np.log(y))
#OR
#You can also use the 'data' argument:
# sns.regplot(x='Healthy life expectancy', y='max_infection_rates', data=data)
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_infection_rates'>

# %% [markdown]
# Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data["Freedom to make life choices"]
y = data["max_infection_rates"]

# Instead of: sns.scatterplot(x, np.log(y))
# Use named arguments with 'x' and 'y':
sns.scatterplot(x=x, y=np.log(y))
# OR
# Use the 'data' argument and specify column names:
# sns.scatterplot(x='Freedom to make life choices', y='max_infection_rates', data=data)
# plt.yscale('log') #This will make the scatterplot more interpretable
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='max_infection_rates'>

# %%
x = data["Freedom to make life choices"]
y = data["max_infection_rates"]

# Use named arguments with 'x' and 'y':
sns.regplot(x=x, y=np.log(y))
# OR
# You can also use the 'data' argument and column names:
# sns.regplot(x='Freedom to make life choices', y='max_infection_rates', data=data)
# plt.yscale('log') #This will make the scatterplot more interpretable
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='max_infection_rates'>
